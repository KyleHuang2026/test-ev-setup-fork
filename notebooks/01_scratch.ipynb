# %% [markdown]
# # test_ev_setup — scratch
#
# Kernel: **Python (test_ev_setup)**. If the kernel picker shows something else,
# switch to it — that's the environment holding this project's packages.

# %%
# %load_ext autoreload
# %autoreload 2

from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
# %matplotlib inline

# %%
import sys

# Confirms the notebook is running the project venv, not a system Python.
print(sys.executable)

# %%
break
